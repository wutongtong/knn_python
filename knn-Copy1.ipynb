# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import cv2
import requests
import re
import urllib2
import os

# %%
image_list = []
size_list = [128,96,64,32,16]
for i1 in range(1,5):    
    for i2 in range(1,5):
        image_name = "/home/wutong/Dataset/CASIA/DatasetB/GEI/nm/GEI_%03d-nm-%02d-090.png"% (i1,i2)
        image_list.append(image_name)
for i1 in range(6,125):
    for i2 in range(1,5):
        image_name = "/home/wutong/Dataset/CASIA/DatasetB/GEI/nm/GEI_%03d-nm-%02d-090.png"% (i1,i2)
        image_list.append(image_name)
        
test_image_list = []
for i1 in range(1,5):    
    for i2 in range(5,7):
        image_name = "/home/wutong/Dataset/CASIA/DatasetB/GEI/nm/GEI_%03d-nm-%02d-090.png"% (i1,i2)
        test_image_list.append(image_name)
for i1 in range(6,125):
    for i2 in range(5,7):
        image_name = "/home/wutong/Dataset/CASIA/DatasetB/GEI/nm/GEI_%03d-nm-%02d-090.png"% (i1,i2)
        test_image_list.append(image_name)

# %%
def img_to_matrix(img, verbose=False):
    """
    takes a filename and turns it into a numpy array of RGB pixels
    """
    img = cv2.imread(img,cv2.CV_8UC1)
    if verbose==True:
        print "changing size from %s to %s" % (str(img.size), str(STANDARD_SIZE))

    img = list(img)
    img = map(list, img)
    img = np.array(img)
    return img

def flatten_image(img):
    """
    takes in an (m, n) numpy array and flattens it 
    into an array of shape (1, m * n)
    """
    s = img.shape[0] * img.shape[1]
    img_wide = img.reshape(1, s)
    return img_wide[0]

# %%
train_image = []
for image in image_list:
    
    img = img_to_matrix(image)
    img = flatten_image(img)
    train_image.append(img)
len(train_image)
test_image = []
for image in test_image_list:
    
    img = img_to_matrix(image)
    img = flatten_image(img)
    test_image.append(img)

# %%
count = 0
label = []
for i,image in enumerate(image_list):
    label.append(count)
    if (i+1)%4 == 0:
        count = count + 1

# %%
neigh = KNeighborsClassifier(n_neighbors=1)

# %%
neigh.fit(train_image, label)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=1, p=2, weights='uniform')

# %%
count = 0
true_label = []
for i,image in enumerate(test_image_list):
    true_label.append(count)
    if (i+1)%2 == 0:
        count = count + 1

# %%
correct = 0.0
for i,image in enumerate(test_image_list):
    predit = neigh.predict(test_image[i])[0]
    print "label:%d, predict:%d" % (true_label[i],predit)
    if predit == true_label[i]:
        correct = correct + 1
acc = correct / len(test_image_list)
print acc
# Out:
# label:0, predict:0
# label:0, predict:0
# label:1, predict:1
# label:1, predict:1
# label:2, predict:2
# label:2, predict:2
# label:3, predict:3
# label:3, predict:3
# label:4, predict:4
# label:4, predict:4
# label:5, predict:5
# label:5, predict:5
# label:6, predict:6
# label:6, predict:6
# label:7, predict:7
# label:7, predict:36
# label:8, predict:8
# label:8, predict:8
# label:9, predict:9
# label:9, predict:9
# label:10, predict:10
# label:10, predict:10
# label:11, predict:11
# label:11, predict:11
# label:12, predict:12
# label:12, predict:12
# label:13, predict:13
# label:13, predict:13
# label:14, predict:14
# label:14, predict:14
# label:15, predict:15
# label:15, predict:15
# label:16, predict:16
# label:16, predict:16
# label:17, predict:17
# label:17, predict:17
# label:18, predict:18
# label:18, predict:18
# label:19, predict:19
# label:19, predict:19
# label:20, predict:20
# label:20, predict:20
# label:21, predict:21
# label:21, predict:21
# label:22, predict:22
# label:22, predict:22
# label:23, predict:111
# label:23, predict:23
# label:24, predict:24
# label:24, predict:24
# label:25, predict:25
# label:25, predict:25
# label:26, predict:26
# label:26, predict:26
# label:27, predict:27
# label:27, predict:27
# label:28, predict:28
# label:28, predict:28
# label:29, predict:29
# label:29, predict:29
# label:30, predict:30
# label:30, predict:30
# label:31, predict:31
# label:31, predict:118
# label:32, predict:32
# label:32, predict:32
# label:33, predict:33
# label:33, predict:33
# label:34, predict:34
# label:34, predict:34
# label:35, predict:35
# label:35, predict:35
# label:36, predict:36
# label:36, predict:36
# label:37, predict:37
# label:37, predict:37
# label:38, predict:38
# label:38, predict:38
# label:39, predict:39
# label:39, predict:39
# label:40, predict:40
# label:40, predict:40
# label:41, predict:41
# label:41, predict:41
# label:42, predict:42
# label:42, predict:42
# label:43, predict:43
# label:43, predict:43
# label:44, predict:44
# label:44, predict:44
# label:45, predict:45
# label:45, predict:45
# label:46, predict:46
# label:46, predict:46
# label:47, predict:47
# label:47, predict:47
# label:48, predict:48
# label:48, predict:48
# label:49, predict:49
# label:49, predict:49
# label:50, predict:50
# label:50, predict:50
# label:51, predict:51
# label:51, predict:51
# label:52, predict:52
# label:52, predict:52
# label:53, predict:53
# label:53, predict:53
# label:54, predict:91
# label:54, predict:54
# label:55, predict:55
# label:55, predict:55
# label:56, predict:56
# label:56, predict:56
# label:57, predict:57
# label:57, predict:57
# label:58, predict:58
# label:58, predict:58
# label:59, predict:61
# label:59, predict:59
# label:60, predict:60
# label:60, predict:60
# label:61, predict:61
# label:61, predict:61
# label:62, predict:62
# label:62, predict:62
# label:63, predict:63
# label:63, predict:63
# label:64, predict:64
# label:64, predict:64
# label:65, predict:65
# label:65, predict:65
# label:66, predict:66
# label:66, predict:66
# label:67, predict:67
# label:67, predict:67
# label:68, predict:68
# label:68, predict:68
# label:69, predict:69
# label:69, predict:69
# label:70, predict:70
# label:70, predict:70
# label:71, predict:71
# label:71, predict:71
# label:72, predict:72
# label:72, predict:72
# label:73, predict:73
# label:73, predict:73
# label:74, predict:74
# label:74, predict:74
# label:75, predict:75
# label:75, predict:75
# label:76, predict:76
# label:76, predict:76
# label:77, predict:77
# label:77, predict:77
# label:78, predict:78
# label:78, predict:78
# label:79, predict:79
# label:79, predict:79
# label:80, predict:80
# label:80, predict:80
# label:81, predict:81
# label:81, predict:81
# label:82, predict:82
# label:82, predict:82
# label:83, predict:83
# label:83, predict:83
# label:84, predict:84
# label:84, predict:84
# label:85, predict:85
# label:85, predict:85
# label:86, predict:86
# label:86, predict:86
# label:87, predict:87
# label:87, predict:87
# label:88, predict:88
# label:88, predict:88
# label:89, predict:89
# label:89, predict:89
# label:90, predict:90
# label:90, predict:90
# label:91, predict:117
# label:91, predict:117
# label:92, predict:92
# label:92, predict:92
# label:93, predict:13
# label:93, predict:93
# label:94, predict:94
# label:94, predict:94
# label:95, predict:95
# label:95, predict:95
# label:96, predict:96
# label:96, predict:96
# label:97, predict:97
# label:97, predict:112
# label:98, predict:98
# label:98, predict:98
# label:99, predict:99
# label:99, predict:99
# label:100, predict:100
# label:100, predict:100
# label:101, predict:101
# label:101, predict:101
# label:102, predict:102
# label:102, predict:102
# label:103, predict:103
# label:103, predict:103
# label:104, predict:104
# label:104, predict:104
# label:105, predict:105
# label:105, predict:105
# label:106, predict:106
# label:106, predict:106
# label:107, predict:107
# label:107, predict:107
# label:108, predict:108
# label:108, predict:108
# label:109, predict:109
# label:109, predict:109
# label:110, predict:110
# label:110, predict:68
# label:111, predict:111
# label:111, predict:111
# label:112, predict:112
# label:112, predict:112
# label:113, predict:118
# label:113, predict:113
# label:114, predict:114
# label:114, predict:114
# label:115, predict:115
# label:115, predict:115
# label:116, predict:116
# label:116, predict:116
# label:117, predict:117
# label:117, predict:117
# label:118, predict:118
# label:118, predict:112
# label:119, predict:119
# label:119, predict:119
# label:120, predict:120
# label:120, predict:120
# label:121, predict:121
# label:121, predict:121
# label:122, predict:122
# label:122, predict:122
# 0.951219512195
